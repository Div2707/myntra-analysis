# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
myntra = pd.read_csv("myntra202305041052.csv")
myntra
# Out:
#               id                                    name
# 0              1              Men Solid Oversized Cotton  \
# 1              2          Men Cotton Pure Cotton T-shirt
# 2              3               Women Pure Cotton T-shirt
# 3              4                Typography Print T-shirt
# 4              5  Printed Round Neck Pure Cotton T-shirt
# ...          ...                                     ...
# 1060208  1060209              Men Slim Tapered Fit Jeans
# 1060209  1060210                    Men Skinny Fit Jeans
# 1060210  1060211                      Men Printed Shorts
# 1060211  1060212                    Men Skinny Fit Jeans
# 1060212  1060213                               Men Jeans
#
#                                                        img asin   price
# 0        https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   532.0  \
# 1        https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   274.0
# ...

# %%
# %time #magic command
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
myntra.shape#1060213 rows and 11 columns
# Out:
# (1060213, 11)

# %%
myntra.columns
# Out:
# Index(['id', 'name', 'img', 'asin', 'price', 'mrp', 'rating', 'ratingTotal',
#        'discount', 'seller', 'purl'],
#       dtype='object')

# %%
myntra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060213 entries, 0 to 1060212
# Data columns (total 11 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1060213 non-null  int64
#  1   name         1060213 non-null  object
#  2   img          1060213 non-null  object
#  3   asin         1060213 non-null  object
#  4   price        1060213 non-null  float64
#  5   mrp          1060213 non-null  float64
#  6   rating       1060213 non-null  float64
#  7   ratingTotal  1060213 non-null  int64
#  8   discount     1060213 non-null  int64
#  9   seller       1060213 non-null  object
#  10  purl         1060213 non-null  object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 89.0+ MB

# %%
myntra.notnull().count()
# Out:
# id             1060213
# name           1060213
# img            1060213
# asin           1060213
# price          1060213
# mrp            1060213
# rating         1060213
# ratingTotal    1060213
# discount       1060213
# seller         1060213
# purl           1060213
# dtype: int64

# %%
unique_asin = myntra["asin"].unique()
print(unique_asin)
# Out:
# ['-']

# %%
unique_rating = myntra["rating"].unique()
print(unique_rating)
# Out:
# [4.1 4.2 4.5 4.  3.9 4.6 4.3 4.8 4.4 0.  5.  4.7 3.8 4.9 3.7 3.5 3.6 2.4
#  3.2 3.4 2.6 2.7 3.  3.3 2.8 3.1 1.  1.8 2.5 2.3 2.  2.2 1.7 2.1 2.9 1.5
#  1.3 1.9 1.6 1.4 1.2 1.1]

# %%
unique_name = myntra["name"].unique()
print(unique_name)

# %%
myntra.head(10)

# %%
myntra1=myntra.drop("asin", axis=1)

# %%
missing_value = myntra1.isnull().sum()
print(missing_value)
# Out:
# id             0
# name           0
# img            0
# price          0
# mrp            0
# rating         0
# ratingTotal    0
# discount       0
# seller         0
# purl           0
# dtype: int64

# %%
myntra1.info()

# %%
#compute the correlation matrix 
corr_matrix = myntra1.corr(numeric_only=True)
print(corr_matrix)
# Out:
#                    id     price       mrp    rating  ratingTotal  discount
# id           1.000000 -0.027656 -0.005568 -0.095192    -0.042522 -0.016309
# price       -0.027656  1.000000  0.918306 -0.101084    -0.014117 -0.013802
# mrp         -0.005568  0.918306  1.000000 -0.114370    -0.020313  0.094421
# rating      -0.095192 -0.101084 -0.114370  1.000000     0.098691 -0.032170
# ratingTotal -0.042522 -0.014117 -0.020313  0.098691     1.000000 -0.005943
# discount    -0.016309 -0.013802  0.094421 -0.032170    -0.005943  1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True ,cmap="coolwarm", square=True)
plt.title("correlation")
plt.show()

# %%
name_counts= myntra1["name"].value_counts()
print(name_counts)
# Out:
# name
# Men Polo Collar T-shirt                    5644
# Gold-Plated Jewellery Set                  5485
# Men Typography Printed T-shirt             4326
# Printed Round Neck T-shirt                 4055
# Men Slim Fit Jeans                         4046
#                                            ...
# Empire Tiered Mini Dress                      1
# Women Slim Jogger Fit Jeans                   1
# Mini Dress With Lace Inserts                  1
# Abstract Waistline Dress                      1
# Men Checked Slim Fit Cotton Track Pants       1
# Name: count, Length: 217738, dtype: int64

# %%
top_10= name_counts.head(10)
top_10
# Out:
# name
# Men Polo Collar T-shirt           5644
# Gold-Plated Jewellery Set         5485
# Men Typography Printed T-shirt    4326
# Printed Round Neck T-shirt        4055
# Men Slim Fit Jeans                4046
# Men Printed T-shirt               3874
# Men Pure Cotton T-shirt           3763
# Women Analogue Watch              3649
# Women Open Toe Flats              2940
# Women Night suit                  2923
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.barplot(x=top_10.index,y=top_10.values)
plt.xticks(rotation=60)
plt.yticks(rotation=60)
plt.xlabel("Name")
plt.ylabel("Count")
plt.title("top 10 values")
plt.tight_layout()
plt.show()

# %%
myntra["mrp"].describe().round()
# Out:
# count    1060213.0
# mean        2668.0
# std         3878.0
# min           25.0
# 25%          999.0
# 50%         1780.0
# 75%         2999.0
# max       257500.0
# Name: mrp, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.histplot(myntra1["price"], bins=30 , kde=True)
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Distribution")
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.histplot(myntra1["ratingTotal"], bins=30 , kde=True)
plt.xlabel("mrp")
plt.ylabel("Frequency")
plt.title("Distribution")
plt.show()

# %%
myntra1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060213 entries, 0 to 1060212
# Data columns (total 10 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1060213 non-null  int64
#  1   name         1060213 non-null  object
#  2   img          1060213 non-null  object
#  3   price        1060213 non-null  float64
#  4   mrp          1060213 non-null  float64
#  5   rating       1060213 non-null  float64
#  6   ratingTotal  1060213 non-null  int64
#  7   discount     1060213 non-null  int64
#  8   seller       1060213 non-null  object
#  9   purl         1060213 non-null  object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 80.9+ MB

# %%
plt.figure(figsize=(10,7))
sns.histplot(myntra1["discount"], bins=30 , kde=True)
plt.xlabel("discount")
plt.ylabel("Frequency")
plt.title("Distribution")
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.histplot(myntra1["seller"], bins=30 , kde=True)
plt.xlabel("mrp")
plt.ylabel("Frequency")
plt.title("Distribution")
plt.show()

# %%
#apply log transforamtion
lg_price=np.log(myntra1["price"])
plt.figure(figsize=(10,7))
sns.histplot(lg_price , bins=28,kde=True)
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Distribution")
plt.show()

# %%
lg_discount=np.log(myntra1["discount"])
plt.figure(figsize=(10,7))
sns.histplot(lg_discount , bins=28,kde=True)
plt.xlabel("discount")
plt.ylabel("Frequency")
plt.title("Distribution")
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
lg_mrp=np.log(myntra1["mrp"])
plt.figure(figsize=(10,7))
sns.histplot(lg_mrp , bins=30,kde=True)
plt.xlabel("mrp")
plt.ylabel("Frequency")
plt.title("Distribution")
plt.show()

# %%
fileterd_rating= myntra1[myntra1["rating"] !=0 ]['rating']

plt.figure(figsize=(10,7))
sns.histplot(fileterd_rating , bins=28,kde=True)
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Distribution")
plt.show()

# %% [markdown]
#  Maximum ratings fall between 4.0 and 4.5

# %%
fileterd_ratingtotal= myntra1[myntra1["ratingTotal"] >10 ]['ratingTotal']

plt.figure(figsize=(10,7))
sns.histplot(fileterd_ratingtotal , bins=28,kde=True)
plt.xlabel("rating total")
plt.ylabel("Frequency")
plt.title("Distribution")
plt.show()

# %%
lg_ratingtotal=np.tan(myntra1['ratingTotal'])
plt.figure(figsize=(10,7))
sns.histplot(lg_ratingtotal , bins=20 , kde=True)
plt.xlabel('Logarithm of Rating Total')
plt.ylabel('Frequency')
plt.title('Distribution of Logarithm of RatingTotal Column')
plt.show()

# %%
#we have find the product with the largest rating
top_15_Rproducts=myntra.nlargest(15,'ratingTotal')
print(top_15_Rproducts[['name','ratingTotal']])
# Out:
#                                          name  ratingTotal
# 271611            Toner-Lotion-Cream-Lip Balm        76400
# 375328            Toner-Lotion-Cream-Lip Balm        76400
# 950168          Men Pack of 2 Printed T-shirt        75100
# 254775              Unisex Skin Care Gift Set        72700
# 353233              Unisex Skin Care Gift Set        72700
# 950167             Pack Of 2 Printed T-shirts        72600
# 989446             Pack Of 2 Printed T-shirts        72600
# 990061  Pack Of 2 Printed Pure Cotton T-shirt        72500
# 88090            Toner-Sunscreen-Lotion-Cream        72400
# 232773           Sustainable Skin & Hair Care        71300
# 325172           Sustainable Skin & Hair Care        71300
# 997932          Men Pack Of 2 Printed TShirts        70500
# 180995              Unisex Skin Care Gift Set        70100
# 271544               Set of 3 Makeup Gift Set        69500
# 230588                Serum-Toner-Scrub-Cream        69100

# %%
#we have find the product with the smallest rating
bottom_5_Rproducts= myntra.nsmallest(5,'ratingTotal')
print(bottom_5_Rproducts[['name','ratingTotal']])
# Out:
#                              name  ratingTotal
# 50          Women Mid Rise Shorts            0
# 51    Puffed Sleeves Casual Shirt            0
# 52     Typography Printed T-shirt            0
# 53      Embroidered Georgette Top            0
# 54  Lace Inserted Pure Cotton Top            0

# %%
#on the basis of discount with their rating
top_5_dproducts=myntra.nlargest(5,'discount')
print(top_5_dproducts[['name','discount','ratingTotal']])
bottom_5_dproducts= myntra.nsmallest(5,'discount')
print(bottom_5_dproducts[['name','discount','ratingTotal']])
# Out:
#                                              name  discount  ratingTotal
# 235289                  Gold-Plated Jewellery Set     19996            0
# 269783                  Gold-Plated Jewellery Set     19996            0
# 706382  Ready to Wear Lehenga Blouse With Dupatta     18501            0
# 714474  Ready to Wear Lehenga Blouse With Dupatta     18501            0
# 728478                Ready to Wear Lehenga Choli     18501            0
#                                 name  discount  ratingTotal
# 25  Men Polo Collar Slim Fit T-shirt         0          295
# 36          Women White Wide T-shirt         0          780
# 54     Lace Inserted Pure Cotton Top         0            0
# 56        Shirt Collar Checked Dress         0            0
# 59          Flared Sleeve Maxi Dress         0            0

# %%
myntra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060213 entries, 0 to 1060212
# Data columns (total 11 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1060213 non-null  int64
#  1   name         1060213 non-null  object
#  2   img          1060213 non-null  object
#  3   asin         1060213 non-null  object
#  4   price        1060213 non-null  float64
#  5   mrp          1060213 non-null  float64
#  6   rating       1060213 non-null  float64
#  7   ratingTotal  1060213 non-null  int64
#  8   discount     1060213 non-null  int64
#  9   seller       1060213 non-null  object
#  10  purl         1060213 non-null  object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 89.0+ MB

# %%
top_5_Mproducts=myntra.nlargest(5,'mrp')
print(top_5_Mproducts[['name','mrp','ratingTotal','discount']])
bottom_5_Mproducts= myntra.nsmallest(5,'mrp')
print(bottom_5_Mproducts[['name','mrp','ratingTotal','discount']])
# Out:
#                                  name       mrp  ratingTotal  discount
# 26184   Bracelet Style Analogue Watch  257500.0            0         0
# 345950  Bracelet Style Analogue Watch  257500.0            0         0
# 447028  Bracelet Style Analogue Watch  257500.0            0         0
# 447791      Men Stainless Steel Watch  146300.0            0         0
# 447801      Men Stainless Steel Watch  140500.0            0         0
#                                  name   mrp  ratingTotal  discount
# 66656   Hair Colour - Natural Black 1  25.0          139         0
# 82496      Hair Colour - Dark Brown 3  25.0           65         0
# 83918   Hair Colour - Natural Brown 4  25.0           79         0
# 203933  Hair Colour - 1 Natural Black  25.0            6         0
# 222626    Hair Colour - Burgundy 3.16  25.0          120         0

# %%
top_5_Iproducts=myntra.nlargest(5,'id')
print(top_5_Iproducts[['name','seller','id']])
bottom_5_Iproducts= myntra.nsmallest(5,'id')
print(bottom_5_Iproducts[['name','seller','id']])
# Out:
#                                name          seller       id
# 1060212                   Men Jeans            IVOC  1060213
# 1060211        Men Skinny Fit Jeans        Roadster  1060212
# 1060210          Men Printed Shorts    WROGN ACTIVE  1060211
# 1060209        Men Skinny Fit Jeans  Mast & Harbour  1060210
# 1060208  Men Slim Tapered Fit Jeans  Flying Machine  1060209
#                                      name                 seller  id
# 0              Men Solid Oversized Cotton  Difference of Opinion   1
# 1          Men Cotton Pure Cotton T-shirt               Roadster   2
# 2               Women Pure Cotton T-shirt              DILLINGER   3
# 3                Typography Print T-shirt                Huetrap   4
# 4  Printed Round Neck Pure Cotton T-shirt               Roadster   5

# %%
lg_discount=np.log(myntra["discount"]+1)
plt.figure(figsize=(10,6))
sns.histplot(lg_discount,bins=20,kde=True)
plt.xlabel("lg_discount")
plt.ylabel("frequency")
plt.title("distribution")
plt.show()

# %%
lg_discount=np.log(myntra["mrp"]+1)
plt.figure(figsize=(10,6))
sns.histplot(lg_discount,bins=20,kde=True)
plt.xlabel("lg_discount")
plt.ylabel("frequency")
plt.title("distribution")
plt.show()

# %%
seller_ginti=myntra['seller'].value_counts()
print(seller_ginti)
# Out:
# seller
# Roadster           10651
# H&M                 6667
# Puma                6579
# max                 6486
# Anouk               6158
#                    ...
# Auggmin                1
# BS AMOR                1
# Bodyguard              1
# TRU HAIR               1
# Zainab chottani        1
# Name: count, Length: 5496, dtype: int64

# %%
#top 5 seller showing them through barplot
OG_sellers=myntra['seller'].value_counts().head(5)
plt.figure(figsize=(10,6))
sns.barplot(x=OG_sellers.index ,y=OG_sellers.values)
plt.xlabel('Seller')
plt.ylabel('Count')
plt.title('Top 5 Sellers by Value Counts')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
#bottom 5 seller showing them through barplot
noob_sellers=myntra['seller'].value_counts().tail(5)
plt.figure(figsize=(10,6))
sns.barplot(x=noob_sellers.index ,y=noob_sellers.values)
plt.xlabel('Seller')
plt.ylabel('Count')
plt.title('Top 5 Sellers by Value Counts')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
#highest rated product
OG_rated_products=myntra.sort_values(by=['rating','ratingTotal'],ascending=[False,False])
print(OG_rated_products[['name','rating','ratingTotal']].head(5))
# Out:
#                                  name  rating  ratingTotal
# 180080  Brightening Foaming Face Wash     5.0          264
# 245742  Brightening Foaming Face Wash     5.0          264
# 376871  Brightening Foaming Face Wash     5.0          264
# 379391  Brightening Foaming Face Wash     5.0          264
# 126865      Multigreens Face Cleanser     5.0          174

# %%
#botom
noob_rated_products=myntra.sort_values(by=['rating','ratingTotal'],ascending=[False,False])
print(noob_rated_products[['name','rating','ratingTotal']].tail(5))
# Out:
#                                             name  rating  ratingTotal
# 1060199                    Men Slim Fit Trousers     0.0            0
# 1060202             Men Solid Cotton Track Pants     0.0            0
# 1060203                Men Colourblocked Joggers     0.0            0
# 1060204  Men Checked Slim Fit Cotton Track Pants     0.0            0
# 1060212                                Men Jeans     0.0            0
